# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
X = [2023, 2024, 2025, 2026]
y = [23,32,21,50]

XX=np.array(X)
yy=np.array(y)

plt.xlabel('years')
plt.ylabel('students')

plt.plot(XX, yy, marker='o', markersize=5, markerfacecolor="#9329ba");

plt.show()
