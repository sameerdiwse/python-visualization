# %%
import matplotlib.pyplot as plt
import numpy as np
# %config Completer.use_jedi = True

# %%
X = [2023, 2024, 2025, 2026]
y1 = [23,32,21,50]
y2 = [27,33,26,51]
XX=np.array(X)
yy1=np.array(y1)
yy2=np.array(y2)

line_styles = dict( marker='o', markersize=5, markerfacecolor="#9329ba", markeredgecolor="black", linestyle='dashdot', linewidth=2, color='black')

plt.plot(XX, yy, **line_styles);
plt.plot(XX, yy2, **line_styles);

plt.title('yearly audit', fontsize=20)
plt.xlabel('Year', fontsize=15, color='blue')
plt.ylabel('No. of Students', fontsize=15, color='blue')
plt.xticks(X);
